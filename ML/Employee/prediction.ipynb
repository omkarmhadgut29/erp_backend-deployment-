# %%
import pandas as pd

# %%
hr_df = pd.read_csv("./hr_data.csv")
hr_df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
hr_df.shape
# Out:
# (14999, 9)

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
satisfaction_df = pd.read_csv("./employee_satisfaction_evaluation.csv")
satisfaction_df
# Out:
#        employee_id  satisfaction_level  last_evaluation
# 0             1003                0.38             0.53
# 1             1005                0.80             0.86
# 2             1486                0.11             0.88
# 3             1038                0.72             0.87
# 4             1057                0.37             0.52
# ...            ...                 ...              ...
# 14994        87670                0.40             0.57
# 14995        87673                0.37             0.48
# 14996        87679                0.37             0.53
# 14997        87681                0.11             0.96
# 14998        87684                0.37             0.52
#
# [14999 rows x 3 columns]

# %%
satisfaction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         14999 non-null  int64
#  1   satisfaction_level  14972 non-null  float64
#  2   last_evaluation     14972 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 351.7 KB

# %%
main_df = pd.merge(hr_df, satisfaction_df, on="employee_id")

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 11 columns]

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.4+ MB

# %%
main_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
main_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
main_df.isnull().sum()
# Out:
# employee_id               0
# number_project            0
# average_montly_hours      0
# time_spend_company        0
# Work_accident             0
# left                      0
# promotion_last_5years     0
# department                0
# salary                    0
# satisfaction_level       27
# last_evaluation          27
# dtype: int64

# %%
main_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# std         0.351719      0.425924               0.144281            0.248714
# min         0.000000      0.000000               0.000000            0.090000
# 25%         0.000000      0.000000               0.000000            0.440000
# 50%         0.000000      0.000000               0.000000            0.640000
# 75%         0.000000      0.000000               0.000000            0.820000
# max         1.000000      1.000000               1.000000            1.000000
#
#        last_evaluation
# count     14972.000000
# mean          0.716125
# std           0.171138
# min           0.360000
# 25%           0.560000
# 50%           0.720000
# 75%           0.870000
# max           1.000000

# %%
main_df.fillna(main_df.mean(), inplace=True)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_19956\1234004495.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   main_df.fillna(main_df.mean(), inplace=True)

# %%
main_df.isnull().sum()
# Out:
# employee_id              0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# satisfaction_level       0
# last_evaluation          0
# dtype: int64

# %%
main_df.drop(columns='employee_id', inplace=True)
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# RandD             0.170267  0.153748               0.034307
# accounting        0.125163  0.265971               0.018253
# hr                0.120433  0.290934               0.020298
# management        0.163492  0.144444               0.109524
# marketing         0.160839  0.236597               0.050117
# product_mng       0.146341  0.219512               0.000000
# sales             0.141787  0.244928               0.024155
# support           0.154778  0.248991               0.008973
# technical         0.140074  0.256250               0.010294
#
#              satisfaction_level  last_evaluation
# department
# IT                     0.617908         0.716750
# RandD                  0.619822         0.712130
# accounting             0.582377         0.718000
# hr                     0.598830         0.709075
# management             0.621850         0.724182
# marketing              0.618442         0.715555
# product_mng            0.619951         0.714703
# sales                  0.614440         0.709719
# support                0.618173         0.722985
# technical              0.607858         0.721298

# %%
main_df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Corelational matrix

# %%
def plot_corr(df,size=10):
    
    corr=df.corr()
    fig,ax=plt.subplots(figsize=(size,size))
    ax.legend()
    cax=ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    

plot_corr(main_df)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# plt.bar(x=main_df['left'], height=main_df['satisfaction_level'])
# it require 51 sec to execute the code

# %%
sns.barplot(x='left', y='satisfaction_level', data=main_df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='satisfaction_level'>

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
sns.barplot(x="number_project", y="satisfaction_level", data=main_df)
# Out:
# <AxesSubplot:xlabel='number_project', ylabel='satisfaction_level'>

# %%
sns.barplot(x="time_spend_company", y="satisfaction_level", data=main_df)
# Out:
# <AxesSubplot:xlabel='time_spend_company', ylabel='satisfaction_level'>

# %%
sns.barplot(x="promotion_last_5years", y="satisfaction_level", data=main_df, hue="left")
# Out:
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='satisfaction_level'>

# %% [markdown]
# ### Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

main_df['salary']=le.fit_transform(main_df['salary'])
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales       1
# 1                  0     1                      0      sales       2
# 2                  0     1                      0      sales       2
# 3                  0     1                      0      sales       1
# 4                  0     1                      0      sales       1
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support       1
# 14995              0     1                      0    support       1
# 14996              0     1                      0    support       1
# 14997              0     1                      0    support       1
# 14998              0     1                      0    support       1
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df['department']=le.fit_transform(main_df['department'])
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  department  salary  \
# 0                  0     1                      0           7       1
# 1                  0     1                      0           7       2
# 2                  0     1                      0           7       2
# 3                  0     1                      0           7       1
# 4                  0     1                      0           7       1
# ...              ...   ...                    ...         ...     ...
# 14994              0     1                      0           8       1
# 14995              0     1                      0           8       1
# 14996              0     1                      0           8       1
# 14997              0     1                      0           8       1
# 14998              0     1                      0           8       1
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
X=main_df.drop(['left'],axis=1)
y = main_df.left

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=89)
scores_dict = {}

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()

dt.fit(X_train.values,y_train.values)
prediction_dt = dt.predict(X_test)

accuracy_dt = accuracy_score(y_test,prediction_dt)*100
# Out:
# e:\Omkar\project work\django app\py_env\py_venv\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
print('Accuracy score : ',accuracy_dt)
scores_dict['DecisionTreeClassifier'] = accuracy_dt
print(classification_report(y_test,prediction_dt))
# Out:
# Accuracy score :  98.04444444444445
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3432
#            1       0.96      0.96      0.96      1068
#
#     accuracy                           0.98      4500
#    macro avg       0.97      0.97      0.97      4500
# weighted avg       0.98      0.98      0.98      4500

# %%
Catagory=['Employee will stay','Employee will Leave']

# %%
X_test.head()
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 5466                3                   264                   4
# 6930                3                   223                   3
# 1218                2                   146                   3
# 14480               6                   139                   6
# 2970                3                   230                   2
#
#        Work_accident  promotion_last_5years  department  salary  \
# 5466               0                      0           8       2
# 6930               0                      0           4       1
# 1218               0                      0           1       1
# 14480              0                      0           9       2
# 2970               0                      0           6       1
#
#        satisfaction_level  last_evaluation
# 5466                 1.00             0.93
# 6930                 0.58             0.78
# 1218                 0.42             0.56
# 14480                0.38             0.86
# 2970                 0.74             0.63

# %%
custom_dt=[[10,500,10,6,4,0,8,0.90,0.89]]

# %%
print(int(dt.predict(custom_dt)))
# Out:
# 0

# %%
Catagory[int(dt.predict(custom_dt))]
# Out:
# 'Employee will Leave'

# %%
dt.feature_importances_
# Out:
# array([0.10491439, 0.09464672, 0.13753837, 0.00242292, 0.00057647,
#        0.01412298, 0.00425762, 0.49699612, 0.14452442])

# %%
feature_importance=pd.DataFrame(dt.feature_importances_,index=X_train.columns,columns=['Importance']).sort_values('Importance',ascending=False)

# %%
feature_importance
# Out:
#                        Importance
# satisfaction_level       0.496996
# last_evaluation          0.144524
# time_spend_company       0.137538
# number_project           0.104914
# average_montly_hours     0.094647
# department               0.014123
# salary                   0.004258
# Work_accident            0.002423
# promotion_last_5years    0.000576

# %%
import pickle

# %%
pickle.dump(dt,open('employee_model.pkl','wb'))

# %%
import joblib
joblib.dump(dt,'employee_model.sav')
# Out:
# ['employee_model.sav']
